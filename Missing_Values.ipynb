# %%
import pandas as pd

# %%
df = pd.read_csv("titanic_train.csv")

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#MCAR --> embarked bec it has no relationship to data

# %%
#show data which is null
df[df['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
#MNAR -> age & cabin

# %%
import numpy as np
df['Cabin_null'] = np.where(df['Cabin'].isnull(),1,0)

# %%
#find % of null val
df['Cabin_null'].mean()
# Out:
# 0.7710437710437711

# %%
df.groupby(['Survived'])['Cabin_null'].mean()
# Out:
# Survived
# 0    0.876138
# 1    0.602339
# Name: Cabin_null, dtype: float64

# %%
#Missing At Random (MAR)

# %%
#all the techniques of handling missing values
#1 mean,med,mode replacement
#2.random sample imputation
#3.capturing NAN values with a new feature
#4.End of Distribution imputation
#5.Arbitrary Imputation
#6.Frequent cat imputation
##Same for cat also

# %%
df1 = pd.read_csv('titanic_train.csv', usecols=['Age','Survived','Fare'])

# %%
df1.head(1)
# Out:
#    Survived   Age  Fare
# 0         0  22.0  7.25

# %%
#percetage of missing vbalues

# %%
df1.isnull().mean()
# Out:
# Survived    0.000000
# Age         0.198653
# Fare        0.000000
# dtype: float64

# %%
#create a function which impute nan value (df, var,med/mean/mode)
def impute_nan(df1,variable,median):
  df1[variable + "_median"] = df1[variable].fillna(median)

# %%
median = df1.Age.median()

# %%
median
# Out:
# 28.0

# %%
impute_nan(df1,'Age',median)

# %%
df1.head()
# Out:
#    Survived   Age     Fare  Age_median
# 0         0  22.0   7.2500        22.0
# 1         1  38.0  71.2833        38.0
# 2         1  26.0   7.9250        26.0
# 3         1  35.0  53.1000        35.0
# 4         0  35.0   8.0500        35.0

# %%
df['Age'].std()
# Out:
# 14.526497332334042

# %%
df1['Age_median'].std()
# Out:
# 13.019696550973201
